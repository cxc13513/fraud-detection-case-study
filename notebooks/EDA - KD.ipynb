# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# u'/Users/kdmytro/Studies/fraud-detection-case-study/notebooks'

# %%
example_df = pd.read_json("../data/raw/example.json")

# %%
example_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 43 columns):
# approx_payout_date    1 non-null int64
# body_length           1 non-null int64
# channels              1 non-null int64
# country               1 non-null object
# currency              1 non-null object
# delivery_method       1 non-null int64
# description           1 non-null object
# email_domain          1 non-null object
# event_created         1 non-null int64
# event_end             1 non-null int64
# event_published       1 non-null int64
# event_start           1 non-null int64
# fb_published          1 non-null int64
# gts                   1 non-null float64
# has_analytics         1 non-null int64
# has_header            0 non-null float64
# has_logo              1 non-null int64
# listed                1 non-null object
# name                  1 non-null object
# name_length           1 non-null int64
# num_order             1 non-null int64
# ...

# %%
example_df.head().T
# Out:
#                                                                     0
# approx_payout_date                                         1364360400
# body_length                                                      1474
# channels                                                           11
# country                                                            US
# currency                                                          USD
# delivery_method                                                     0
# description         <p><span style="font-size: medium; font-family...
# email_domain                               dreamprojectfoundation.org
# event_created                                              1361291193
# event_end                                                  1363928400
# event_published                                            1361978554
# event_start                                                1363914000
# ...

# %%
len(example_df.description[0])
# Out:
# 1474

# %%
df = pd.read_json("../data/raw/data.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
dfgroup.acct_type
# Out:
# 500      fraudster
# 501      fraudster
# 1500     fraudster
# 2000       premium
# 3000     fraudster
# 3001     fraudster
# 4000     fraudster
# 4001     fraudster
# 5000       premium
# 5500     fraudster
# 6000       premium
# 7500     fraudster
# 8000     fraudster
# 8001     fraudster
# 11500    fraudster
# 11501      premium
# Name: acct_type, dtype: object

# %%
df.acct_type.unique()
# Out:
# array([u'fraudster_event', u'premium', u'spammer_warn', u'fraudster',
#        u'spammer_limited', u'spammer_noinvite', u'locked', u'tos_lock',
#        u'tos_warn', u'fraudster_att', u'spammer_web', u'spammer'], dtype=object)

# %%
df.groupby("acct_type").count()['description'].sort_values(ascending=False)
# Out:
# acct_type
# premium             12373
# fraudster_event       851
# fraudster             437
# spammer_limited       218
# spammer_warn          144
# tos_warn               91
# spammer_noinvite       84
# tos_lock               77
# locked                 54
# fraudster_att           5
# spammer_web             2
# spammer                 1
# Name: description, dtype: int64

# %%
plt.style.use('ggplot')

# %%
acct_types = df.groupby("acct_type").count()['description'].sort_values(ascending=False)
fig = plt.figure()
ax = acct_types.plot(kind='bar')
# plt.bar(np.arange(len(acct_types)),acct_types.values)
ax.set_xticklabels(acct_types.index)

# %%
df.head(3).T
# Out:
#                                                                     0  \
# acct_type                                             fraudster_event
# approx_payout_date                                         1266062400
# body_length                                                      3852
# channels                                                            5
# country                                                            US
# currency                                                          USD
# delivery_method                                                     0
# description         <p><a href="http://s432.photobucket.com/albums...
# email_domain                                                gmail.com
# event_created                                              1262739706
# event_end                                                  1265630400
# event_published                                           1.26311e+09
# ...

# %%
df.groupby('fraud')['user_age'].apply(np.mean)
# Out:
#        approx_payout_date  body_length  channels  delivery_method  \
# fraud
# False        1.351254e+09  3886.994557  6.377645         0.475537
# True         1.347687e+09  1508.886311  4.149265         0.073380
#
#        event_created     event_end  event_published   event_start  \
# fraud
# False   1.345874e+09  1.350822e+09     1.342905e+09  1.350545e+09
# True    1.345333e+09  1.347255e+09     1.318542e+09  1.346777e+09
#
#        fb_published          gts  ...    org_twitter  sale_duration  \
# fraud                             ...
# False      0.137841  2481.679602  ...       4.687960      49.827631
# True       0.022428  1911.214362  ...       0.294023      14.125957
#
#        sale_duration2  show_map    user_age  user_created  user_type  \
# fraud
# False       53.950245  0.852883  402.683073  1.311082e+09   2.819304
# True        16.544470  0.756381   87.152359  1.337804e+09   1.619490
#
#        venue_latitude  venue_longitude  fraud
# fraud
# ...

# %%
df[[len(x) >= 1 for x in df.payee_name]].groupby("acct_type").count()['description'].sort_values(ascending=False)
# Out:
# acct_type
# premium             2988
# spammer_limited       47
# spammer_warn          38
# tos_warn              33
# spammer_noinvite      29
# fraudster_event       20
# fraudster             10
# locked                 9
# tos_lock               3
# Name: description, dtype: int64

# %%
df.gts.max
# Gross ticket sales
# Out:
# <bound method Series.max of 0            0.00
# 1          868.02
# 2         3500.00
# 3         1167.35
# 4         2313.15
# 5          302.57
# 6          832.64
# 7          220.64
# 8         3706.36
# 9          535.84
# 10         750.00
# 11         685.44
# 12         178.00
# 13         833.14
# 14        1038.56
# 15        2723.44
# 16        2146.44
# 17          34.62
# 18        1996.00
# 19       14424.18
# 20        3855.28
# 21         106.49
# 22         268.70
# 23         132.00
# 24        1326.48
# 25         107.48
# 26         634.98
# 27        5860.00
# 28       10438.00
# 29        1485.14
#            ...
# 14307      154.00
# 14308    16615.46
# 14309     4709.83
# 14310       16.82
# 14311      460.00
# 14312     2709.86
# 14313     1020.00
# 14314     1272.08
# 14315      115.72
# 14316    12319.15
# 14317      143.56
# 14318      472.16
# 14319      750.00
# 14320       18.98
# 14321      618.94
# 14322       35.00
# 14323      203.71
# ...

# %%
df[df.email_domain == 'gmail.com'].groupby(['acct_type']).count()['gts'].sort_values(ascending=False)
# Out:
# acct_type
# premium             2592
# fraudster_event      234
# fraudster            108
# spammer_limited       52
# spammer_warn          31
# spammer_noinvite      28
# tos_warn              22
# locked                18
# tos_lock               9
# fraudster_att          3
# Name: gts, dtype: int64

# %%
df.groupby(['email_domain']).count()['gts'].sort_values(ascending=False)
# Out:
# email_domain
# gmail.com                   3097
# yahoo.com                    792
# hotmail.com                  399
# aol.com                      198
# live.com                      80
# me.com                        75
# ymail.com                     68
# comcast.net                   60
# generalassemb.ly              58
# yahoo.co.uk                   52
# kineticevents.com             52
# hotmail.co.uk                 48
# improvboston.com              46
# sippingnpainting.com          39
# claytonislandtours.com        37
# lidf.co.uk                    35
# racetonowhere.com             35
# live.fr                       33
# greatworldadventures.com      31
# yahoo.ca                      31
# shaw.ca                       28
# sbcglobal.net                 26
# msn.com                       25
# mac.com                       25
# live.co.uk                    24
# guardian.co.uk                24
# joonbug.com                   23
# rocketmail.com                23
# ...

# %%
plt.hist([len(x) for x in df.org_desc],bins=100)
# Out:
# (array([  1.11100000e+04,   1.73600000e+03,   6.29000000e+02,
#           3.57000000e+02,   1.46000000e+02,   9.10000000e+01,
#           7.60000000e+01,   2.70000000e+01,   3.20000000e+01,
#           1.40000000e+01,   1.20000000e+01,   4.00000000e+00,
#           1.60000000e+01,   6.00000000e+00,   4.00000000e+00,
#           4.00000000e+00,   1.00000000e+00,   3.00000000e+00,
#           2.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   3.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   1.40000000e+01,   8.00000000e+00,
#           3.00000000e+00,   1.50000000e+01,   3.00000000e+00,
#           3.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
# ...

# %%
df.ix[0].description
# Out:
# u'<p><a href="http://s432.photobucket.com/albums/qq49/digusonline/?action=view&amp;current=supersunday.jpg" target="_blank"><img src="http://i432.photobucket.com/albums/qq49/digusonline/supersunday.jpg" border="0" alt="Photobucket" /></a></p>\r\n<p>\xa0</p>\r\n<p style="text-align: center;"><font size="3"><strong>Party Starz Entertaintment &amp; Diverse International Group Presents...<br /></strong></font><br /><font face="tahoma,arial,helvetica,sans-serif" size="4"><strong>The Official\xa0"99 Hour No Sleep" Super Bowl </strong></font></p>\r\n<p style="text-align: center;"><font face="tahoma,arial,helvetica,sans-serif" size="4"><strong>Weekend </strong></font><font face="tahoma,arial,helvetica,sans-serif" size="4"><strong>Grand Finale</strong></font></p>\r\n<p><br /><span style="font-family: Times New Roman,serif;"><font size="3"><font face="tahoma,arial,helvetica,sans-serif">No matter who wins or loses, this post-game party cannot be missed! Enjoy the drink specials and all night mu
# ...

# %%
field = 'user_created'
pd.to_datetime(df[field],unit='s')
# Out:
# 0       2009-11-30 20:45:50
# 1       2010-08-04 17:26:16
# 2       2010-04-29 16:43:08
# 3       2010-09-07 14:35:02
# 4       2010-11-05 19:07:45
# 5       2010-03-14 15:05:10
# 6       2009-01-31 21:39:11
# 7       2010-10-28 14:28:23
# 8       2011-01-07 19:22:01
# 9       2010-10-28 14:28:23
# 10      2009-01-08 17:43:32
# 11      2009-11-14 06:37:44
# 12      2008-11-04 11:57:00
# 13      2009-10-18 09:16:01
# 14      2010-07-13 18:34:35
# 15      2010-01-28 20:13:54
# 16      2010-01-28 20:13:54
# 17      2011-02-12 03:04:26
# 18      2009-03-04 15:00:30
# 19      2011-02-12 00:24:02
# 20      2011-02-12 09:13:01
# 21      2010-01-26 06:28:00
# 22      2009-11-30 17:43:39
# 23      2009-12-02 20:34:19
# 24      2010-11-12 17:56:44
# 25      2009-09-12 04:18:43
# 26      2011-01-21 02:26:17
# 27      2010-06-30 15:54:05
# 28      2010-07-14 19:47:32
# 29      2008-12-08 04:52:16
#                 ...
# 14307   2011-06-22 21:25:54
# 14308   2012-01-19 07:46:05
# ...

# %%
    date_fields = ['approx_payout_date',
                    'event_created',
                    'event_end',
                    'event_published',
                    'event_start',
                    'user_created']
df[date_fields].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 6 columns):
# approx_payout_date    14337 non-null int64
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# user_created          14337 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 784.1 KB

# %%
df.event_published.max()
# Out:
# 1381608321.0

# %%
df.event_published.min()
# Out:
# 0.0

# %%
df.event_published.mean()
# Out:
# 1340853730.833474

# %%
len(df.event_published[df.event_published < 1300000000])
# Out:
# 753

# %%
# map(lambda x: x , df.ticket_types)

df['fraud'] = map(lambda x: 'fraud' in x, df.acct_type)

# %%
fraud_df = df[df.fraud]

# %%
np.mean(len(x) for x in fraud_df.ticket_types])
# Out:
# 1.7300850734725444

# %%
fraud_df.iloc[0].ticket_types
# Out:
# [{u'availability': 1,
#   u'cost': 25.0,
#   u'event_id': 527017,
#   u'quantity_sold': 0,
#   u'quantity_total': 800},
#  {u'availability': 1,
#   u'cost': 50.0,
#   u'event_id': 527017,
#   u'quantity_sold': 0,
#   u'quantity_total': 100},
#  {u'availability': 1,
#   u'cost': 550.0,
#   u'event_id': 527017,
#   u'quantity_sold': 0,
#   u'quantity_total': 20}]

# %%
np.mean([len(x) for x in fraud_df.ticket_types])
# Out:
# 1.7300850734725444

# %%
np.mean([np.mean([y['cost'] for y in x]) for x in fraud_df.ticket_types if x])
# Out:
# 209.67919814604085

# %%
fraud_df['avg_ticket_price'] = [np.mean([y['cost'] for y in x]) for x in fraud_df.ticket_types]
fraud_df['avg_ticket_price']
# Out:
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 0         208.333333
# 26        250.000000
# 51         33.307692
# 54        500.000000
# 70         30.000000
# 128       300.000000
# 130       140.760000
# 131       683.333333
# 140       140.760000
# 144       175.714286
# 149        91.875000
# 161         8.460000
# 177       100.000000
# 181       185.500000
# 183       233.333333
# 187        45.000000
# 202       100.000000
# 206       300.000000
# 212        40.000000
# 219         7.500000
# 248       150.000000
# 250        50.000000
# 259        23.130000
# 262         2.505000
# 263       310.000000
# 272       163.510000
# ...

# %%
good_df = df[~df.fraud]

# %%
np.mean([len(x) for x in good_df.ticket_types])
# Out:
# 2.7899417356639069

# %%
np.mean([np.mean([y['cost'] for y in x]) for x in good_df.ticket_types if x])
# Out:
# 100.7208892593261

# %%
good_df['avg_ticket_price'] = [np.mean([y['cost'] for y in x]) for x in good_df.ticket_types]
good_df['avg_ticket_price']
# Out:
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 1          35.000000
# 2          93.510000
# 3          13.666667
# 4         101.750000
# 5          11.750000
# 6         157.114000
# 7          14.000000
# 8         250.000000
# 9          14.000000
# 10         36.980000
# 11         30.000000
# 12        121.390000
# 13         35.000000
# 14        112.500000
# 15         10.000000
# 16         10.000000
# 17         10.000000
# 18        474.080000
# 19        195.000000
# 20         14.628571
# 21        100.000000
# 22         50.000000
# 23          9.400000
# 24         17.500000
# 25         50.000000
# 27          8.460000
# ...

# %%
np.mean([y['cost'] for x in good_df.ticket_types for y in x])
# Out:
# 138.09179764783468

# %%
(good_df.avg_ticket_price.fillna(good_df.avg_ticket_price.mode()))
# Out:
# 1          35.000000
# 2          93.510000
# 3          13.666667
# 4         101.750000
# 5          11.750000
# 6         157.114000
# 7          14.000000
# 8         250.000000
# 9          14.000000
# 10         36.980000
# 11         30.000000
# 12        121.390000
# 13         35.000000
# 14        112.500000
# 15         10.000000
# 16         10.000000
# 17         10.000000
# 18        474.080000
# 19        195.000000
# 20         14.628571
# 21        100.000000
# 22         50.000000
# 23          9.400000
# 24         17.500000
# 25         50.000000
# 27          8.460000
# 28       1973.080000
# 29         25.000000
# 30         30.506667
# 31         12.500000
#             ...
# 14301      27.450000
# 14302       3.200000
# 14303       2.386667
# 14305       2.386667
# 14306      41.535000
# 14307      10.666667
# 14308      15.000000
# 14309     518.800000
# 14310      15.000000
# 14311      18.955000
# 14312      29.210526
# 14313      21.333333
# ...

# %%
good_df.avg_ticket_price.mode()
# Out:
# 0    10.0
# dtype: float64

# %%
(fraud_df.avg_ticket_price.fillna(fraud_df.avg_ticket_price.mode()))
# Out:
# 0         208.333333
# 26        250.000000
# 51         33.307692
# 54        500.000000
# 70         30.000000
# 128       300.000000
# 130       140.760000
# 131       683.333333
# 140       140.760000
# 144       175.714286
# 149        91.875000
# 161         8.460000
# 177       100.000000
# 181       185.500000
# 183       233.333333
# 187        45.000000
# 202       100.000000
# 206       300.000000
# 212        40.000000
# 219         7.500000
# 248       150.000000
# 250        50.000000
# 259        23.130000
# 262         2.505000
# 263       310.000000
# 272       163.510000
# 275        90.000000
# 289              NaN
# 296       140.000000
# 307        10.000000
#             ...
# 14037      50.000000
# 14041     250.000000
# 14043      50.352500
# 14044    1000.000000
# 14051     230.000000
# 14054      40.995000
# 14060      85.000000
# 14073      45.000000
# 14098      89.990000
# 14114     122.000000
# 14125     825.000000
# 14128    1250.000000
# ...

# %%
good_df.iloc[0].ticket_types
# Out:
# [{u'availability': 1,
#   u'cost': 35.0,
#   u'event_id': 786878,
#   u'quantity_sold': 22,
#   u'quantity_total': 50},
#  {u'availability': 1,
#   u'cost': 35.0,
#   u'event_id': 786878,
#   u'quantity_sold': 3,
#   u'quantity_total': 50}]

# %%
good_df.iloc[0].gts
# Out:
# 868.01999999999998

# %%
fraud_df.gts
# Out:
# 0            0.00
# 26         634.98
# 51         321.28
# 54       16276.45
# 70          65.28
# 128      37592.10
# 130        150.00
# 131       4664.85
# 140        450.00
# 144        598.06
# 149       8991.21
# 161        180.00
# 177        319.47
# 181        857.52
# 183       1164.46
# 187          0.00
# 202        958.41
# 206       1904.94
# 212         86.38
# 219          0.00
# 248      20188.09
# 250       3107.39
# 259        570.00
# 262          6.27
# 263       3128.54
# 272        188.92
# 275         93.24
# 289          0.00
# 296        477.27
# 307       6830.62
#            ...
# 14037      212.98
# 14041      952.47
# 14043     1040.65
# 14044     1039.95
# 14051     2755.11
# 14054      612.43
# 14060      362.68
# 14073       48.47
# 14098     4500.06
# 14114      362.80
# 14125     5631.65
# 14128    10566.98
# 14131      219.26
# 14140     6986.37
# 14149        0.00
# 14164      794.22
# 14187      344.85
# 14203        0.00
# 14229     9727.16
# ...

# %%
good_df.count()
# Out:
# acct_type             13044
# approx_payout_date    13044
# body_length           13044
# channels              13044
# country               12963
# currency              13044
# delivery_method       13040
# description           13044
# email_domain          13044
# event_created         13044
# event_end             13044
# event_published       13039
# event_start           13044
# fb_published          13044
# gts                   13044
# has_analytics         13044
# has_header             8409
# has_logo              13044
# listed                13044
# name                  13044
# name_length           13044
# num_order             13044
# num_payouts           13044
# object_id             13044
# org_desc              13044
# org_facebook          13040
# org_name              13044
# org_twitter           13040
# payee_name            13044
# payout_type           13044
# previous_payouts      13044
# sale_duration         13007
# sale_duration2        13044
# ...

# %%
fraud_df.count()
# Out:
# acct_type             1293
# approx_payout_date    1293
# body_length           1293
# channels              1293
# country               1293
# currency              1293
# delivery_method       1281
# description           1293
# email_domain          1293
# event_created         1293
# event_end             1293
# event_published       1199
# event_start           1293
# fb_published          1293
# gts                   1293
# has_analytics         1293
# has_header             519
# has_logo              1293
# listed                1293
# name                  1293
# name_length           1293
# num_order             1293
# num_payouts           1293
# object_id             1293
# org_desc              1293
# org_facebook          1238
# org_name              1293
# org_twitter           1238
# payee_name            1293
# payout_type           1293
# previous_payouts      1293
# sale_duration         1175
# sale_duration2        1293
# show_map              1293
# ...

# %%
df['time_to_event'] = pd.to_datetime(df.event_created,unit='s') - pd.to_datetime(df.user_created,unit='s')

# %%
df['time_to_event'] = df['time_to_event'].dt.days

# %%
df[['time_to_event','fraud']]
# Out:
#        time_to_event  fraud
# 0                 36   True
# 1                149  False
# 2                214  False
# 3                889  False
# 4                 34  False
# 5                299  False
# 6                705  False
# 7                 71  False
# 8                  0  False
# 9                 71  False
# 10               729  False
# 11               429  False
# 12               813  False
# 13               465  False
# 14               197  False
# 15               371  False
# 16               371  False
# 17                 2  False
# 18               709  False
# 19               124  False
# 20                 2  False
# 21               382  False
# 22               448  False
# 23               453  False
# 24               109  False
# 25               535  False
# 26                41   True
# 27               258  False
# 28               244  False
# 29               862  False
# ...              ...    ...
# 14307            569  False
# ...

# %%
df.groupby(['fraud']).max('time_to_event')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-225-d3318ce576ca> in <module>()
# ----> 1 df['fraud'].max('time_to_event')
#
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    5630                                       skipna=skipna)
#    5631         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 5632                             numeric_only=numeric_only)
#    5633
#    5634     return set_function_name(stat_func, name, cls)
#
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2313         if isinstance(delegate, np.ndarray):
#    2314             # Validate that 'axis' is consistent with Series's single axis.
# ...

# %%
email_domain = df.groupby('email_domain')['fraud'].agg({lambda x: x.sum()/float(x.count())})
email_domain.columns = ['email_score']
df.join(email_domain, on='email_domain')
# Out:
#              acct_type  approx_payout_date  body_length  channels country  \
# 0      fraudster_event          1266062400         3852         5      US
# 1              premium          1296720000         3499         0      US
# 2              premium          1296172800         2601         8      US
# 3              premium          1388966400        12347         6      IE
# 4              premium          1297900800         2417        11      US
# 5              premium          1300496400          117         6      US
# 6              premium          1297909800           28         5      US
# 7              premium          1296709200          974        12      US
# 8              premium          1298185200         4388         4      US
# 9              premium          1297314000          974        12      US
# 10             premium          1296504000         4397         8      US
# 11             premium          1298070000         1679        10      US
# ...

# %%
email_domain.to_dict()['email_score']['gmail.com']
# Out:
# 0.11139812721989022

# %%
zz.unstack(level=0)
result.reset_index
# Out:
#           email_domain
# <lambda>  .com                         0.0
#           10-12businessclub.co.uk      0.0
#           1015.com                     0.0
#           101cs.co.uk                  0.0
#           1121.us                      0.0
#           126.com                      1.0
#           1313main.com                 0.0
#           140ventures.com              0.0
#           1415broad.ca                 0.0
#           14stamps.com                 0.0
#           163.com                      0.0
#           1904musichall.com            0.0
#           1989.usna.com                0.0
#           19sieunhan.com               1.0
#           1eventsmedia.co.uk           0.0
#           200peachtree.com             0.0
#           20vic.com                    0.0
#           247csf.com.au                0.0
#           27thWardChicago.org          0.0
#           2funny.org.uk                0.0
#           2waydevelopment.com          0.0
# ...

# %%
fraud_df.description
# Out:
# 0        <p><a href="http://s432.photobucket.com/albums...
# 26       <h1 class="post">Welcome</h1>\r\n<p> </p>\r\n<...
# 51       <p><span style="font-size: x-large;">Okay ever...
# 54       <h3><strong><strong><span style="font-family: ...
# 70
# 128      <p><span style="font-size: medium; color: #ff0...
# 130      <p>TODAY'S LIVE Conference Call is scheduled f...
# 131      <p> ALL PROCEEDS WILL GO TOWARD BETTERING OUR ...
# 140      <p>TODAY'S LIVE Conference Call is scheduled f...
# 144      <p>Join us for two full days of continuing edu...
# 149      <h1><span style="font-size: x-large;">You've d...
# 161                <p>The Kimmel Center - Verizon Hall</p>
# 177      <p><span class="vevent"><span class="descripti...
# 181      <p>Join us in Beautiful, Historic New Bern on ...
# 183      <p style="text-align: left;"><strong><span sty...
# 187      <p><span style="font-family: arial black,avant...
# 202      <p> </p>\r\n<table style="width: 801px;" borde...
# 206
# 212
# 219
# ...

# %%
good_df.description
# Out:
# 1        <p>Join us for a quick, one-night, community-b...
# 2        <h3><span class="subcategory"><strong>Teacher ...
# 3        <p style="margin-bottom: 1.3em; padding-bottom...
# 4        <p>Writers and filmmakers need to understand t...
# 5        <p>Come join the Bluegrass Stallions as they t...
# 6                         <p> </p>\r\n<p> </p>\r\n<p> </p>
# 7        <p><em>WHEN JEKYLL MET HYDE</em></p>\r\n<p>The...
# 8        <p style="text-align: center;"><font face="boo...
# 9        <p><em>WHEN JEKYLL MET HYDE</em></p>\r\n<p>The...
# 10       <p style="text-align: center;"><font size="4" ...
# 11       <p><a  fishy with local Dept. of Fish and Game...
# 12       <div style="mso-element: frame; mso-element-fr...
# 13       <p><span class="text"><strong><em><font size="...
# 14       <p class="MsoNormal" style="text-align: center...
# 15       <table style="width: 100%;" border="0">\r\n<tb...
# 16       <table style="width: 100%;" border="0">\n<tbod...
# ...
